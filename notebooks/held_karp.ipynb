# %%
from Req import Map, gen_poly, gen_ran, held_karp
from Req.dynamic import shortest_segment
from time import time

# %%
times = []
for i in range(3, 18):
    t0 = time()
    dummy = held_karp(gen_ran(i))
    t1 = time()
    t = t1 - t0
    times.append(t)
    print(f"Time elapsed: {round(t, 3)} seconds")
    dummy.show2d()
# Out:
# Time elapsed: 0.001 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.003 seconds
# Time elapsed: 0.008 seconds
# Time elapsed: 0.029 seconds
# Time elapsed: 0.067 seconds
# Time elapsed: 0.191 seconds
# Time elapsed: 0.532 seconds
# Time elapsed: 1.171 seconds
# Time elapsed: 2.856 seconds
# Time elapsed: 7.44 seconds
# Time elapsed: 16.314 seconds
# Time elapsed: 38.457 seconds
