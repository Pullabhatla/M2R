# %% [markdown]
# # Brute force search

# %%
from Req import Map, minimal_tour, gen_poly, gen_ran
from time import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Roots of Unity
#
# We shall experiment with the regular polygons generated by the roots of unity in the complex plane and represent our results as a Map in 2D space. In the program below, we find that the brute force search becomes impractical beyond the octagon.

# %%
times = []
for i in range(3, 9):
    t0 = time()
    dummy = minimal_tour(gen_poly(i))
    t1 = time()
    t = t1 - t0
    times.append(t)
    print(f"Time elapsed: {round(t, 3)} seconds")
    dummy.show2d()
# Out:
# Time elapsed: 0.003 seconds
# Time elapsed: 0.012 seconds
# Time elapsed: 0.061 seconds
# Time elapsed: 0.403 seconds
# Time elapsed: 3.737 seconds
# Time elapsed: 34.876 seconds

# %%
plt.plot([i for i in range(3,9)], times)
plt.xlabel("Size of map")
plt.ylabel("Evaluation time in seconds")
plt.show()

# %% [markdown]
# ## Random maps

# %%
times = []
for i in range(3, 9):
    t0 = time()
    dummy = minimal_tour(gen_ran(i))
    t1 = time()
    t = t1 - t0
    times.append(t)
    print(f"Time elapsed: {round(t, 3)} seconds")
    dummy.show2d()
# Out:
# Time elapsed: 0.002 seconds
# Time elapsed: 0.01 seconds
# Time elapsed: 0.053 seconds
# Time elapsed: 0.382 seconds
# Time elapsed: 3.599 seconds
# Time elapsed: 34.523 seconds

# %%
plt.plot([i for i in range(3,9)], times)
plt.xlabel("Size of map")
plt.ylabel("Evaluation time in seconds")
plt.show()
