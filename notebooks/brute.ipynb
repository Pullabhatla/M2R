# %% [markdown]
# # Brute force search

# %%
from Req import Map, brute_tour, gen_poly, gen_ran
from time import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Roots of Unity
#
# We shall experiment with the regular polygons generated by the roots of unity in the complex plane and represent our results as a Map in 2D space. In the program below, we find that the brute force search becomes impractical beyond the octagon.

# %%
times = []
for i in range(3, 11):
    t0 = time()
    dummy = brute_tour(gen_poly(i))
    t1 = time()
    t = t1 - t0
    times.append(t)
    print(f"Time elapsed: {round(t, 3)} seconds")
    dummy.show2d()
# Out:
# Time elapsed: 0.0 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.007 seconds
# Time elapsed: 0.054 seconds
# Time elapsed: 0.686 seconds
# Time elapsed: 6.519 seconds

# %%
plt.plot([i for i in range(3,11)], times)
plt.xlabel("Size of map")
plt.ylabel("Evaluation time in seconds")
plt.show()

# %% [markdown]
# ## Random maps

# %%
times = []
for i in range(3, 11):
    t0 = time()
    dummy = brute_tour(gen_ran(i))
    t1 = time()
    t = t1 - t0
    times.append(t)
    print(f"Time elapsed: {round(t, 3)} seconds")
    dummy.show2d()
# Out:
# Time elapsed: 0.0 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.001 seconds
# Time elapsed: 0.002 seconds
# Time elapsed: 0.008 seconds
# Time elapsed: 0.129 seconds
# Time elapsed: 0.853 seconds
# Time elapsed: 6.84 seconds

# %%
plt.plot([i for i in range(3, 11)], times)
plt.xlabel("Size of map")
plt.ylabel("Evaluation time in seconds")
plt.show()
